# %%
import requests

api_key = 'aa95852e920247648cefc5aee2c8f843'  # Замени на свой ключ
url = ('https://newsapi.org/v2/everything?'
       'q=экономика OR финансы OR деньги OR бизнес OR рынки OR акции OR облигации OR отчётность&'  # Ключевые слова
       'language=ru&'
       'from=2024-07-20&to=2024-08-19&'  # Источники: РБК, Ведомости, Коммерсант
       'sortBy=publishedAt&'  # Сортировка по дате публикации
       f'apiKey={api_key}')

response = requests.get(url)
news_data = response.json()

news_data
# Out:
# {'status': 'ok',
#  'totalResults': 2958,
#  'articles': [{'source': {'id': None, 'name': 'Gazeta.ru'},
#    'author': 'Газета.Ru',
#    'title': 'Протестующие попытались прорваться на съезд демократов в Чикаго',
#    'description': 'Участники массовой акции протеста попытались прорваться на территорию съезда Демократической партии США, который проходит в Чикаго. Об этом сообщает РИА Новости со ссылкой на своего корреспондента.\n\nПо словам журналиста, часть протестующих ...',
#    'url': 'https://www.gazeta.ru/social/news/2024/08/20/23727259.shtml',
#    'urlToImage': 'https://img.gazeta.ru/files3/837/13132837/AP_20175613118205-pic905-895x505-90411.jpg',
#    'publishedAt': '2024-08-19T23:18:19Z',
#    'content': ': .Ru (Gazeta.Ru)\r\n: «.», 1067761730376, 7743625728\r\n : 125239, , , , 67\r\n:\r\n117105,\r\n. ,\r\n , .9, .1'},
#   {'source': {'id': None, 'name': 'News2.ru'},
#    'author': 'Kalman',
#    'title': 'Лукашенко допустил ликвидацию Зеленского Будановым*',
# ...
